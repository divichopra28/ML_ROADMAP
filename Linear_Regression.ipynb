# %% [markdown]
# **Performing Linear Regression on Student Performance Dataset**

# %% [markdown]
# Import Dataset
# This is student performance dataset , which we can use for implementing linear regression method

# %%
import pandas as pd 
df=pd.read_csv("StudentsPerformance.csv")
